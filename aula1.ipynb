# %%
import apache_beam as beam

# %%
p1 = beam.Pipeline()

# %%
voos = (
p1
| "Importar dados" >> beam.io.ReadFromText("voos_sample.csv")
| "Separar por virgula" >> beam.Map(lambda record: record.split(","))
| "Gravar dados" >> beam.io.WriteToText("output/voos.txt")
)

# %%
p1.run()
